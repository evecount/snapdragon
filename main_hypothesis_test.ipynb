# %%
import os
import sys

# Environment Sentinel: Verify presence of core dependencies
try:
    import numpy as np
    import matplotlib.pyplot as plt
    print("Project SNAPDRAGON Environment: [COHERENT]")
except ImportError as e:
    print(f"Project SNAPDRAGON Environment: [DECOHERED] - Missing {e.name}")
    print("Please ensure 'numpy' and 'matplotlib' are installed.")

# Path Resolver: Support for Colab/Kaggle/Local environments
PROJECT_ROOT = os.getcwd()
print(f"Operational Path: {PROJECT_ROOT}")

# %% [markdown]
# # **Project SNAPDRAGON: Sovereign Decision Stack [v13.1]**
# ### **The Triple Crown: Snapdragon, DSMF & EPIC**
#
# This workbook verifies the complete logical stack of the SNAPDRAGON protocol.
#
# #### **The Three Pillars (Full Stack)**
# 1. **Snapdragon (Filter)**: High-velocity $O(1)$ noise clearance.
# 2. **DSMF (Context)**: Nested fractal sigmoid depth.
# 3. **EPIC (Diagnostic)**: Geometric entropy as a detector for **Systemic Operational Futility**.

# %% [markdown]
# ## **Step 1: The DSMF Simulation (Fractal Context)**
# Instead of a flat binary transition, the DSMF uses **nested sigmoids**. This creates 'contextual containers' during the snap, allowing the system to understand the 'Refractive Jitter' that classical models ignore.

# %%
import numpy as np
import matplotlib.pyplot as plt

def sigmoid(x, alpha=1.0, center=0):
    return 1 / (1 + np.exp(-alpha * (x - center)))

def dsmf_fractal_lock(x, depth_gamma=3):
    """
    The Double Sigmoid Mencius Function.
    Nests micro-sigmoids within a macro-sigmoid to capture fractal context.
    """
    # Macro Curve (The Primary State Transition)
    macro = sigmoid(x, alpha=10, center=0.5)
    
    # Micro-Sigmoids (The Hidden Context Containers)
    micro = sum([0.1 * sigmoid(x, alpha=100, center=0.4 + 0.05*i) for i in range(depth_gamma)])
    
    return macro + micro

x_range = np.linspace(0, 1, 1000)
y_dsmf = dsmf_fractal_lock(x_range)

plt.figure(figsize=(10, 5))
plt.plot(x_range, y_dsmf, color='magenta', linewidth=2, label='DSMF (Fractal Lock)')
plt.title("DSMF: Recursive Fractal Contextualization")
plt.xlabel("Input Signal Entropy")
plt.ylabel("Decision Confidence")
plt.grid(alpha=0.2)
plt.legend()
plt.show()

print("DSMF Simulation: Notice the 'steps' in the curve—these are the hidden context containers.")

# %% [markdown]
# ## **Step 2: Residual Error Indexing (REI) Proof**
# REI uses the floating-point 'jitter' (the tiny error between classical FPU math and our SNAPDRAGON approximation) as a **Carrier Wave**.

# %%
def rei_extract(classical_val, snap_val):
    """
    Residual Error Indexing.
    Extracts the 'Stealth Bit' from the difference between FPU and Kernel logic.
    """
    error = abs(classical_val - snap_val)
    return 1 if error > 0.00175 else 0

print(f"Signal A REI Signature: {rei_extract(1.258, 1.256)} (0 = Public Signal)")
print(f"Signal B REI Signature: {rei_extract(1.258, 1.255)} (1 = STEALTH BIT DETECTED)")

# %% [markdown]
# ## **Step 3: The EPIC Layer (Futility Detection)**
# EPIC maps the temporal evolution of the snap into a geometric configuration. If the system enters a state of **Systemic Operational Futility** (geometric disorder), it triggers a resource lock.

# %%
def calculate_epic_metric(state_entropy):
    """
    Simulates Geometric Disorder (Coordination Number Distribution).
    In a state of futility, disorder spikes despite resource consumption.
    """
    # Baseline Order vs. Geometric Jitter
    baseline = 0.5
    geometric_disorder = state_entropy * np.random.uniform(0.8, 1.5)
    
    return geometric_disorder

def epic_audit(metric_value):
    """Status Check."""
    if metric_value > 0.85:
        return "FUTILITY STATE DETECTED (System Decoherence)"
    return "SYSTEM COHERENT"

test_entropy_low = 0.4
test_entropy_high = 0.9

print(f"[Audit 1] Entropy {test_entropy_low}: {epic_audit(calculate_epic_metric(test_entropy_low))}")
print(f"[Audit 2] Entropy {test_entropy_high}: {epic_audit(calculate_epic_metric(test_entropy_high))}")

# %% [markdown]
# ## **Step 4: The Sovereign Decision Stack (Integrated Test)**
# Final verification. We use the **Magic Hex** to identify the event, the **DSMF** for context, and **EPIC** for coherence.

# %%
dataset = np.random.normal(0.6324, 0.1, 100)
results = []

for x in dataset:
    # 1. SNAP (Velocity)
    is_snap = 1 if x > 0.62 else 0
    # 2. DSMF (Depth)
    confidence = dsmf_fractal_lock(x)
    # 3. EPIC (Health)
    health = epic_audit(calculate_epic_metric(confidence))
    
    results.append((is_snap, confidence, health))

print(f"Simulation Complete. Processed {len(dataset)} points through the Triple Crown Stack.")
print("Sample Result (Topological Hub):", results[0])

# %% [markdown]
# ---
# **Project SNAPDRAGON v13.1 [Institutional Release]**
# Reference [EPIC_WHITE_PAPER.md](docs/EPIC_WHITE_PAPER.md) for deeper diagnostic theory.
